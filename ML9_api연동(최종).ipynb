# %% [markdown]
# 모델파일이 커서 코랩 content파일에 업로드가 안될시엔 zip로 압축 후 업로드 해주시고, 하단 셀 실행하여 압축해제해서 사용해주시면 됩니다.

# %%
# !unzip my_finetuned_model_v2.zip
# Out:
# Archive:  my_finetuned_model_v2.zip
#    creating: my_finetuned_model_v2/
#   inflating: my_finetuned_model_v2/adapter_config.json
#   inflating: my_finetuned_model_v2/adapter_model.safetensors
#   inflating: my_finetuned_model_v2/added_tokens.json
#   inflating: my_finetuned_model_v2/merges.txt
#   inflating: my_finetuned_model_v2/README.md
#   inflating: my_finetuned_model_v2/special_tokens_map.json
#   inflating: my_finetuned_model_v2/tokenizer.json
#   inflating: my_finetuned_model_v2/tokenizer_config.json
#   inflating: my_finetuned_model_v2/training_args.bin
#   inflating: my_finetuned_model_v2/vocab.json

# %% [markdown]
# api KEY에 대한 보안상 이슈로 .env파일 생성 후 env파일에서 api KEY를 끌어오도록 합니다.
#
# ***코랩 내에서는 .env파일 업로드가 불가하기에 api키가 담긴 env파일을 생성하는것으로 사용. (vscode에선 .env파일 업로드 가능)***

# %%
# api키가 담긴 .env파일을 생성합니다.
# %%writefile .env
GEMINI_API_KEY=AIzaSyCcSfvf83DOVogBC9yxHEDGZVaB66U9LTQ
# Out:
# Writing .env

# %%
# 1. 필수 라이브러리 및 Ngrok 클라이언트 설치
print("\n--- 2. 라이브러리 및 Ngrok 설치 시작 ---")
# !pip install -r requirements.txt
# !pip install pyngrok

# 2. 최신 Ngrok 클라이언트 다운로드 및 설치 (구형 버전 오류 해결)
# 시스템 PATH에 최신 Ngrok을 설치하는 공식 명령어
# !curl -sSL https://ngrok-agent.s3.amazonaws.com/ngrok.asc \
| sudo tee /etc/apt/trusted.gpg.d/ngrok.asc >/dev/null \
&& echo "deb https://ngrok-agent.s3.amazonaws.com bookworm main" | sudo tee /etc/apt/sources.list.d/ngrok.list \
&& sudo apt update \
&& sudo apt install ngrok

# 3. Ngrok 인증 토큰 설정 (실제 토큰으로 교체)
# <YOUR_AUTH_TOKEN> 대신 실제 토큰을 입력합니다.
#!ngrok config add-authtoken <YOUR_AUTH_TOKEN>
# !ngrok config add-authtoken 35gwm2IKuCjoJlEN4KvcqdOEjvn_632x8TrQPYkHmzxKHnRCi
# Out:
# --- 1. 모델 어댑터 압축 해제 ---
# Archive:  my_finetuned_model_v2.zip
#   inflating: my_finetuned_model_v2/adapter_config.json
#   inflating: my_finetuned_model_v2/adapter_model.safetensors
#   inflating: my_finetuned_model_v2/added_tokens.json
#   inflating: my_finetuned_model_v2/merges.txt
#   inflating: my_finetuned_model_v2/README.md
#   inflating: my_finetuned_model_v2/special_tokens_map.json
#   inflating: my_finetuned_model_v2/tokenizer.json
#   inflating: my_finetuned_model_v2/tokenizer_config.json
#   inflating: my_finetuned_model_v2/training_args.bin
#   inflating: my_finetuned_model_v2/vocab.json
#
# --- 2. 라이브러리 및 Ngrok 설치 시작 ---
# ...
# deb https://ngrok-agent.s3.amazonaws.com bookworm main
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# ...

# %%
# 4. 서버 구동 (백그라운드 실행)
print("\n--- 4. 서버 구동 시작 ---")
# !python app.py &
# Out:
# --- 5. 서버 구동 시작 ---
# 2025-11-19 21:16:10.811126: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 21:16:10.828660: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763586970.849908   12379 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763586970.856515   12379 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#이전에 백그라운드로 실행된 캐시가 남아있어서 app.py 실행이 안될경우 5000번 포트를 사용중인 파일을 kill 하는 명령어
# !fuser -k 5000/tcp

# %% [markdown]
# app.py 실행 후 터미널 열어서
# ngrok http 5000
# 입력 후 나오는 ngrok의 공유 url을 통해 postman에서 json 데이터 입력 시 결과값을 출력 받을 수 있습니다.
